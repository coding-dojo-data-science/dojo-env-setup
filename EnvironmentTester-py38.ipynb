# %% [markdown]
# # Environment Tester

# %% [markdown]
# - The following notebook is meant to be a quick summary/verification of your computers environment.
# - Please run all of the cells to get all of the information displayed.
#     - Either Press `Shift + Enter` to run each cell
#     - OR Click on `Kernel`> `Restart & Run All`

# %% [markdown]
# ## Conda

# %%
## GET CURRENT ENVIRONMENT INFO
# %conda info
# Out:
#      active environment : dojo-env
#     active env location : /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env
#             shell level : 2
#        user config file : /Users/codingdojo/.condarc
#  populated config files : /opt/homebrew/Caskroom/miniforge/base/.condarc
#                           /Users/codingdojo/.condarc
#           conda version : 4.13.0
#     conda-build version : not installed
#          python version : 3.9.10.final.0
#        virtual packages : __osx=12.4=0
#                           __unix=0=0
#                           __archspec=1=arm64
#        base environment : /opt/homebrew/Caskroom/miniforge/base  (writable)
#       conda av data dir : /opt/homebrew/Caskroom/miniforge/base/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-arm64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-arm64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://conda.anaconda.org/conda-forge/osx-arm64
#                           https://conda.anaconda.org/conda-forge/noarch
#           package cache : /opt/homebrew/Caskroom/miniforge/base/pkgs
#                           /Users/codingdojo/.conda/pkgs
#        envs directories : /opt/homebrew/Caskroom/miniforge/base/envs
#                           /Users/codingdojo/.conda/envs
#                platform : osx-arm64
#              user-agent : conda/4.13.0 requests/2.27.1 CPython/3.9.10 Darwin/21.5.0 OSX/12.4
#                 UID:GID : 502:20
#              netrc file : None
#            offline mode : False
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
## CHECK PYTHON VERSION (should be 3.8.13)
# !python --version
# Out:
# Python 3.8.13

# %%
## Folder path to python
# !which python
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/bin/python

# %% [markdown]
# ## Python Packages

# %%
# 1.4.2
import pandas as pd
pd.__version__
# Out:
# '1.4.2'

# %%
# 1.22.4
import numpy as np
np.__version__
# Out:
# '1.22.4'

# %%
# 3.5.2
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.__version__
# Out:
# '3.5.2'

# %%
# 0.11.2
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
# 1.1.1
import sklearn as sk
from sklearn.preprocessing import StandardScaler
sk.__version__
# Out:
# '1.1.1'

# %%
# 1.8.1
import scipy as sp
from scipy import stats
sp.__version__
# Out:
# '1.8.1'

# %%
# 1.0.2
import pymysql
pymysql.__version__
# Out:
# '1.0.2'

# %%
# 0.13.2
import statsmodels
import statsmodels.api as sm
statsmodels.__version__
# Out:
# '0.13.2'

# %%
# 1.8.5
import pmdarima as pmd
pmd.__version__
# Out:
# '1.8.5'

# %%
# 0.40.0
import shap
shap.__version__
# Out:
# '0.40.0'

# %%
# 0.9.1
import imblearn
imblearn.__version__
# Out:
# '0.9.1'

# %%
# # 0.6.7
# import dython 
# dython.__version__

# %%
# # 0.20.0
# import mlxtend 
# mlxtend.__version__

# %%
# 0.2.7
import interpret
interpret.__version__
# Out:
# '0.2.7'

# %%
## As long as m1 mac installed the m1 env, this should work
import tensorflow as tf
tf.__version__
# Out:
# '2.9.2'

# %%
# 1.1.1
import sklearn
sklearn.__version__
# Out:
# '1.1.1'

# %%
# 0.10.0
import sktime 
sktime.__version__
# Out:
# '0.10.0'

# %%
# 1.0
import prophet
prophet.__version__
# Out:
# '1.0'

# %% [markdown]
# ## Jupyter Notebook Extensions

# %%
# IF THE ABOVE CELL ERROR'D:
# !pip install jupyter_contrib_nbextensions
# !jupyter contrib nbextension install --user
# !jupyter nbextension enable jupyter_nbextensions_configurator
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (0.5.1)
# Requirement already satisfied: notebook>=4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.4.12)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.4.1)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.3.3)
# Requirement already satisfied: pyyaml in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.0)
# Requirement already satisfied: ipython-genutils in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (5.3.0)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-latex-envs>=1.3.8 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (1.4.6)
# Requirement already satisfied: lxml in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (4.9.0)
# Requirement already satisfied: nbconvert>=4.2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.5.0)
# Requirement already satisfied: tornado in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (6.1)
# Requirement already satisfied: jupyter-core in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter_contrib_nbextensions) (4.10.0)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (62.3.4)
# Requirement already satisfied: ipython in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (8.4.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.6.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: tinycss2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: nbformat>=5.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (5.4.0)
# Requirement already satisfied: pygments>=2.4.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.12.0)
# Requirement already satisfied: bleach in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (5.0.0)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (21.3)
# Requirement already satisfied: jinja2>=3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.15.0)
# Requirement already satisfied: argon2-cffi in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: pyzmq>=17 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (23.1.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.5.5)
# Requirement already satisfied: ipykernel in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (6.15.0)
# Requirement already satisfied: prometheus-client in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (7.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook>=4.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: fastjsonschema in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbformat>=5.1->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from nbformat>=5.1->nbconvert>=4.2->jupyter_contrib_nbextensions) (4.6.0)
# Requirement already satisfied: ptyprocess in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from terminado>=0.8.3->notebook>=4.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.3.1)
# Requirement already satisfied: webencodings in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (1.15.0)
# Requirement already satisfied: debugpy>=1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: psutil in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (0.1.3)
# Requirement already satisfied: appnope in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipykernel->notebook>=4.0->jupyter_contrib_nbextensions) (0.1.3)
# Requirement already satisfied: decorator in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: backcall in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: stack-data in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.3.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (3.0.29)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from packaging->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=4.2->jupyter_contrib_nbextensions) (5.8.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=4.2->jupyter_contrib_nbextensions) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: wcwidth in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: cffi>=1.0.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (1.15.0)
# Requirement already satisfied: executing in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from stack-data->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: pure-eval in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from stack-data->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: asttokens in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from stack-data->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: pycparser in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=5.1->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.8.0)
# [I 21:36:35 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 21:36:35 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband -> rubberband
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/rubberband/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/rubberband/main.css
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/rubberband/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/rubberband/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/rubberband/rubberband.yaml
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down -> scroll_down
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/scroll_down/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/scroll_down/config.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/scroll_down/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/scroll_down/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/hinterland -> hinterland
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hinterland/hinterland.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hinterland/hinterland.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hinterland/README.md
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/snippets -> snippets
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets/snippets.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets/snippets.json
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets/snippets-demo.gif
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/toggle_all_line_numbers -> toggle_all_line_numbers
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toggle_all_line_numbers/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toggle_all_line_numbers/main.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toggle_all_line_numbers/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toggle_all_line_numbers/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/notify -> notify
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/notify/notify.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/notify/notify.mp3
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/notify/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/notify/notify.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/notify/notification.png
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/runtools -> runtools
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/cellstate.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/runtools_execute.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/annotations.odg
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/runtools.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/main.css
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/runtools_nb.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/runtools_marker.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/runtools_show_hide.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/runtools_lock.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/demo.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/runtools/gutter.css
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/tree-filter -> tree-filter
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/tree-filter/tree-filter.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/tree-filter/index.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/tree-filter/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/tree-filter/demo.gif
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/table_beautifier -> table_beautifier
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/table_beautifier/main.css
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/table_beautifier/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/table_beautifier/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/table_beautifier/table_beautifier.yaml
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/freeze -> freeze
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/freeze/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/freeze/config.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/freeze/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/freeze/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/exercise2 -> exercise2
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/exercise2/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/exercise2/exercise2.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/exercise2/main.css
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/exercise2/image.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/exercise2/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/exercise2/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/execution_dependencies -> execution_dependencies
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/execution_dependencies/execution_dependencies.yml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/execution_dependencies/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/execution_dependencies/execution_dependencies.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/skill -> skill
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/skill/skill.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/skill/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/skill/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/skill/skill.yaml
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/splitcell -> splitcell
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/splitcell/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/splitcell/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/splitcell/splitcell.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/splitcell/splitcell.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/autosavetime -> autosavetime
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/autosavetime/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/autosavetime/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/autosavetime/autosavetime.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/autosavetime/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap -> select_keymap
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/select_keymap/select_keymap.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/select_keymap/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/select_keymap/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/select_keymap/select_keymap.yaml
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/livemdpreview -> livemdpreview
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/livemdpreview/livemdpreview.yml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/livemdpreview/livemdpreview.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/gist_it -> gist_it
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/gist_it/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/gist_it/gist_it.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/gist_it/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/gist_it/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/cell_filter -> cell_filter
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/cell_filter/cell_filter.yml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/cell_filter/cell_filter.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/cell_filter/README.md
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/scratchpad -> scratchpad
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/scratchpad/LICENSE
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/scratchpad/scratchpad.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/scratchpad/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/scratchpad/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/scratchpad/scratchpad.css
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/scratchpad/demo.gif
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/toc2 -> toc2
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/toc2.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/demo_dark.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/main.css
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/demo3.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/demo2.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/toc2.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/demo.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/toc2/image.png
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate -> nbTranslate
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/nbTranslate/nbTranslate.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/nbTranslate/nbTranslate.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/nbTranslate/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/nbTranslate/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/nbTranslate/demo1.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/nbTranslate/demo2.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/nbTranslate/languages.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/nbTranslate/mutils.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/equation-numbering -> equation-numbering
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/equation-numbering/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/equation-numbering/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/equation-numbering/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/equation-numbering/info.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/equation-numbering/button.png
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/navigation-hotkeys -> navigation-hotkeys
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/navigation-hotkeys/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/navigation-hotkeys/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/navigation-hotkeys/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/navigation-hotkeys/hotkeys.yaml
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu -> snippets_menu
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_menu.css
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenu_python.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/config.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenu_markdown.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/thumbnail.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/screenshot1.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/screenshot2.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/screenshot3.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/examples_for_custom.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy_ufuncs.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/numba.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy_assumptions.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/astropy.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/pandas.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy_polynomial.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy_constants.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/matplotlib.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy_functions.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/h5py.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy_special.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/python_regex.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/python.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/printview -> printview
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/printview/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/printview/printview-button.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/printview/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/printview/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/printview/printview.yaml
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/export_embedded -> export_embedded
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/export_embedded/export_embedded.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/export_embedded/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/export_embedded/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/export_embedded/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/autoscroll -> autoscroll
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/autoscroll/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/autoscroll/autoscroll.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/autoscroll/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/autoscroll/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input -> hide_input
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_input/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_input/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_input/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_input/hide-input.yaml
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_input_all -> hide_input_all
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_input_all/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_input_all/hide_input_all.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_input_all/hide_input_all_show.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_input_all/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_input_all/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_input_all/hide_input_all_hide.png
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor -> keyboard_shortcut_editor
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/keyboard_shortcut_editor.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_comma.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_blank.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_success.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/main.css
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_reset_disabled.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_add_new_link.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/main.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_dropdown.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/quickhelp_shim.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_add_new_select_action.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/kse_components.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_undefined_key.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_conflict.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/keyboard_shortcut_editor/readme_menu_item.png
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/help_panel -> help_panel
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/help_panel/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/help_panel/help_panel_ext.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/help_panel/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/help_panel/help_panel_ext_fullscreen.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/help_panel/help_panel.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/help_panel/help_panel.css
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/help_panel/help_panel.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/help_panel/img/handle-v.png
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/move_selected_cells -> move_selected_cells
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/move_selected_cells/README.md
# ...
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/2to3.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/isort.yaml
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/demo-py.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/README_2to3.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/2to3.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/README_isort.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/code_prettify.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/autopep8.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/demo-R.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/isort.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/2to3.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/isort.yaml
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/demo-py.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/README_2to3.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/2to3.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/README_isort.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/code_prettify.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/autopep8.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/demo-R.gif
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/isort.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/2to3.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/code_prettify/isort.yaml
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/load_tex_macros -> load_tex_macros
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/load_tex_macros/load_tex_macros.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/load_tex_macros/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/load_tex_macros/readme.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/load_tex_macros/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_contrib_nbextensions/nbextensions/hide_header -> hide_header
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_header/hide_header.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_header/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/hide_header/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/jupyter_highlight_selected_word/static/highlight_selected_word -> highlight_selected_word
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/highlight_selected_word/configurator.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/highlight_selected_word/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/highlight_selected_word/main.js
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.8/site-packages/latex_envs/static -> latex_envs
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/icon.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/latex_envs.yaml
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/configuration_toolbar.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/bibInNb4.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/example_user_envs.json
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/envsLatex.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/main_toolbar.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/envsLatex.json
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/thmsInNb4.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/initNb.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/latex_envs.css
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/latex_envs.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/bibtex2.js
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/example.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/IEEEtran.bst
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/documentation.pdf
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/configuration_toolbar.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/biblio_ipython.bib
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/config_toolbar.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/documentation.tex
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/main_toolbar.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/README.md
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc.ipynb
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/LaTeX_envs_menu.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc.tex
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/header.tex
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/Toggles.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc.html
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/example.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/.ipynb_checkpoints/latex_env_doc-checkpoint.ipynb
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_51_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_48_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_50_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_49_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_52_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_41_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_43_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_24_2.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_47_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_45_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_26_2.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_42_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_23_2.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_44_0.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_27_2.png
# [I 21:36:35 InstallContribNbextensionsApp] Up to date: /Users/codingdojo/Library/Jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_46_0.png
# [I 21:36:35 InstallContribNbextensionsApp] - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions items to config in /Users/codingdojo/.jupyter
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /Users/codingdojo/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.4.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
# [I 21:36:35 InstallContribNbextensionsApp] Enabling notebook extension contrib_nbextensions_help_item/main...
# [I 21:36:35 InstallContribNbextensionsApp]       - Validating: OK
# [I 21:36:35 InstallContribNbextensionsApp] - Editing config: /Users/codingdojo/.jupyter/jupyter_nbconvert_config.json
# [I 21:36:35 InstallContribNbextensionsApp] --  Configuring nbconvert template path
# [I 21:36:35 InstallContribNbextensionsApp] --  Configuring nbconvert preprocessors
# [I 21:36:35 InstallContribNbextensionsApp] - Writing config: /Users/codingdojo/.jupyter/jupyter_nbconvert_config.json
# [I 21:36:35 InstallContribNbextensionsApp] --  Writing updated config file /Users/codingdojo/.jupyter/jupyter_nbconvert_config.json
# Enabling notebook extension jupyter_nbextensions_configurator...
#       - Validating: problems found:
#         - require?  X jupyter_nbextensions_configurator

# %%
# !jupyter nbextension enable toc2/main
# !jupyter nbextension enable collapsible_headings/main
# !jupyter nbextension enable ruler/main
# !jupyter nbextension enable livemdpreview/livemdpreview 
# !jupyter nbextension enable spellchecker/main
# Out:
# Enabling notebook extension toc2/main...
#       - Validating: OK
# Enabling notebook extension collapsible_headings/main...
#       - Validating: OK
# Enabling notebook extension ruler/main...
#       - Validating: OK
# Enabling notebook extension livemdpreview/livemdpreview...
#       - Validating: OK
# Enabling notebook extension spellchecker/main...
#       - Validating: OK

# %%
## CHeck if nbextensions installed
# !jupyter nbextension list
# Out:
# Known nbextensions:
#   config dir: /Users/codingdojo/.jupyter/nbconfig
#     notebook section
#       nbextensions_configurator/config_menu/main  enabled
#       - Validating: problems found:
#         - require?  X nbextensions_configurator/config_menu/main
#       contrib_nbextensions_help_item/main  enabled
#       - Validating: OK
#       jupyter_nbextensions_configurator  enabled
#       - Validating: problems found:
#         - require?  X jupyter_nbextensions_configurator
#       toc2/main  enabled
#       - Validating: OK
#       collapsible_headings/main  enabled
#       - Validating: OK
#       ruler/main  enabled
#       - Validating: OK
#       livemdpreview/livemdpreview  enabled
#       - Validating: OK
#       spellchecker/main  enabled
#       - Validating: OK
#       execute_time/ExecuteTime  enabled
#       - Validating: OK
#     tree section
#       nbextensions_configurator/tree_tab/main  enabled
#       - Validating: problems found:
#         - require?  X nbextensions_configurator/tree_tab/main
#   config dir: /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/etc/jupyter/nbconfig
#     notebook section
#       jupyterlab-plotly/extension  enabled
#       - Validating: OK
#       jupyter-js-widgets/extension  enabled
#       - Validating: OK

# %% [markdown]
# ## Shell/Terminal

# %%
## Which shell - mac users (zsh or bash?)
shell = !echo $SHELL
shell
# Out:
# ['/bin/zsh']

# %%
# !echo $PATH
# Out:
# /opt/homebrew/bin:/opt/homebrew/sbin:/opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Apple/usr/bin

# %% [markdown]
# ### Display the Profile For Your Terminal/GitBash

# %%
import os
## Checking .bash_profile or .zshrc
if 'zsh' in shell[0]:
    print(f'[i] Using .zshrc')
    fname = r"~/.zshrc"
else:
    print(f'[i] Using .bash_profile')
    fname = r"~/.bash_profile"
    
profile = !cat {fname}
print('\n'.join(profile))
# Out:
# [i] Using .zshrc
# # >>> conda initialize >>>
# # !! Contents within this block are managed by 'conda init' !!
# __conda_setup="$('/opt/homebrew/Caskroom/miniforge/base/bin/conda' 'shell.zsh' 'hook' 2> /dev/null)"
# if [ $? -eq 0 ]; then
#     eval "$__conda_setup"
# else
#     if [ -f "/opt/homebrew/Caskroom/miniforge/base/etc/profile.d/conda.sh" ]; then
#         . "/opt/homebrew/Caskroom/miniforge/base/etc/profile.d/conda.sh"
#     else
#         export PATH="/opt/homebrew/Caskroom/miniforge/base/bin:$PATH"
#     fi
# fi
# unset __conda_setup
# # <<< conda initialize <<<
#
# export CENSUS_API_KEY="3893033f682428f0e5a14542f9c15dae8359a3ff"
#
#
# alias jnb="jupyter notebook"
# alias cd_notes="cd /Users/codingdojo/Documents/GitHub/_NOTES_REPOS/"
# alias cd_curric="cd Documents/GitHub/_CURRICULUM/"
# alias mysql="/usr/local/mysql/bin/mysql"
#
#
# eval "$(/opt/homebrew/bin/brew shellenv)"
#
#
# ## Prompt formatting - default = "\h:\W \u\$ "
# # export PS1="\W \$ "
# export PS1="%n %1~ \$ "
#
#
# conda activate dojo-env
# # conda activate dojo-env
# # export PYTHONPATH="$PYTHONPATH:/Users/codingdojo/Documents/GitHub/_CURRICULUM/_BONUS/making-your-own-python-modules-and-package"

# %% [markdown]
# # Package Tests

# %% [markdown]
# ## Pandas Profiling

# %%
import pandas as pd
df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRsXeEswMPJqEh9xpXed0eJYaQf_aKkNCypU4TKvGrS_hucLW2IWUxrVBjlKQJR4Z_EQFE-YR4UUuTz/pub?output=csv",
                index_col=0)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
from pandas_profiling import ProfileReport
report = ProfileReport(df)
# report

# %% [markdown]
# ## Scikit-learn

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer, make_column_selector,make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import train_test_split

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
## dropping column that are not helpful
bad_cols = ['Name','Ticket']
df.drop(columns=bad_cols,inplace=True)

# %%
## Specifying root names of types of features to loop through and filter out from df
target_col = 'Survived'
drop_cols = ['Cabin']

y = df[target_col].copy()
X = df.drop(columns=[target_col,*drop_cols]).copy()

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=321)
y_train.value_counts(1)
# Out:
# 0    0.627246
# 1    0.372754
# Name: Survived, dtype: float64

# %%
## feature selectors
cat_sel = make_column_selector(dtype_include='object')
num_sel = make_column_selector(dtype_include='number')

# %%
## create pipelines and column transformer
num_transformer = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scale',StandardScaler())])

cat_transformer = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='constant',fill_value='MISSING')),
    ('encoder',OneHotEncoder(sparse=False,handle_unknown='ignore',
                             drop='first'))])
                           
                           
                           
## COMBINE BOTH PIPELINES INTO ONE WITH COLUMN TRANSFORMER
preprocessor=ColumnTransformer(transformers=[
    ('num',num_transformer,num_sel),
    ('cat',cat_transformer,cat_sel)], verbose_feature_names_out=False)

preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scale', StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x2c2567df0>),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x2c2567dc0>)],
#                   verbose_feature_names_out=False)

# %%
## Fit preprocessing pipeline on training data and pull out the feature names and X_cols
preprocessor.fit(X_train)
feature_names = preprocessor.get_feature_names_out()
## Transform X_traian,X_test and remake dfs
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          index=X_train.index, columns=feature_names)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          index=X_test.index, columns=feature_names)
X_train_df
# Out:
#                Pclass       Age     SibSp     Parch      Fare  Sex_male  \
# PassengerId
# 255          0.827283  0.883963 -0.449355  2.332612 -0.236040       0.0
# 470          0.827283 -2.332883  1.337367  0.940132 -0.255202       0.0
# 813         -0.371470  0.404433 -0.449355 -0.452347 -0.431083       1.0
# 298         -1.570222 -2.232981  0.444006  2.332612  2.401428       0.0
# 82           0.827283 -0.075096 -0.449355 -0.452347 -0.451165       1.0
# ...               ...       ...       ...       ...       ...       ...
# 713         -1.570222  1.443415  0.444006 -0.452347  0.402304       1.0
# 810         -1.570222  0.244590  0.444006 -0.452347  0.424393       0.0
# 800          0.827283  0.004825  0.444006  0.940132 -0.156969       0.0
# 125         -1.570222  1.922945 -0.449355  0.940132  0.910117       1.0
# 539          0.827283 -0.115057 -0.449355 -0.452347 -0.350757       1.0
#
#              Embarked_MISSING  Embarked_Q  Embarked_S
# PassengerId
# 255                       0.0         0.0         1.0
# 470                       0.0         0.0         0.0
# 813                       0.0         0.0         1.0
# 298                       0.0         0.0         1.0
# 82                        0.0         0.0         1.0
# ...                       ...         ...         ...
# 713                       0.0         0.0         1.0
# 810                       0.0         0.0         1.0
# 800                       0.0         0.0         1.0
# 125                       0.0         0.0         1.0
# 539                       0.0         0.0         1.0
#
# [668 rows x 9 columns]

# %%
def evaluate_classification(model,X,y_true, classes=None, normalize='true',
                            cmap="Blues",  label="Test Data", figsize=(5,3)): 

    ## Get Predictions
    y_pred = model.predict(X)
    
    ## Classification Report / Scores 
    dashes = '---'*20
    print(dashes)
    print(f"[i] CLASSIFICATION REPORT FOR: {label}")
    print(dashes)
    
    print(metrics.classification_report(y_true,y_pred,
                                        target_names=classes))
    # print(dashes)
    

    ## Plot a confusion matrix
    fig, ax = plt.subplots(figsize=figsize)
    metrics.ConfusionMatrixDisplay.from_predictions(y_true,y_pred,
                                                         normalize=normalize,
                                                        cmap=cmap,ax=ax)
#     cm = metrics.confusion_matrix(y_true,y_pred,normalize=normalize,)
#     # plt.figure(figsize=figsize)
#     ax = sns.heatmap(cm, annot=True,square=True,cmap=cmap)

    if classes != None:
        ## Label classes
        ax.set_xticklabels(classes)
        ax.set_yticklabels(classes,rotation=0)

    ## Add axis labels & title
    ax.set_ylabel('True Classes')
    ax.set_xlabel('Predicted Classes')
    ax.set_title('Confusion Matrix');
    plt.show()

# %%
import sklearn.metrics as metrics

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train_df,y_train)
evaluate_classification(rf,X_test_df,y_test)
# Out:
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       130
#            1       0.82      0.84      0.83        93
#
#     accuracy                           0.86       223
#    macro avg       0.85      0.85      0.85       223
# weighted avg       0.86      0.86      0.86       223

# %% [markdown]
# ## Shap

# %%
import shap 
print(shap.__version__)
shap.initjs()
# Out:
# 0.40.0
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
## Initialize an explainer with the model
explainer = shap.TreeExplainer(rf)

## Calculaate shap values for test data
shap_values = explainer.shap_values(X_test_df,y_test)
len(shap_values)
# Out:
# 2

# %%
shap.summary_plot(shap_values[1],X_test_df,max_display=40)

# %% [markdown]
# ## sktime

# %%
import sktime
